# %%
import pandas as pd
import folium
import geopandas as gpd
from shapely.geometry import Point, MultiPolygon, Polygon

# %% [markdown]
# ### Add the neighborhood information for the houses

# %%
#Load the data
houses = pd.read_csv('Data/houses.csv')
houses.head(2)
# Out:
#     latitude   longitude           address            property_type  \
# 0  34.190532 -118.145081  2694 Raymond Ave  Single Family Residence
# 1  33.899958 -117.990815  14520 Dunnet Ave  Single Family Residence
#
#    home_size  lot_size  year_built  parcel_number  zoning  sex_offenders  ...  \
# 0     1199.0    7207.0      1950.0     5835035008  LCR175              5  ...
# 1     1254.0    6033.0      1957.0     8065036010    LMR1              2  ...
#
#                                                  url  bedrooms  bathrooms  \
# 0  https://www.realtytrac.com/property/ca/altaden...       3.0        2.0
# 1  https://www.realtytrac.com/property/ca/la-mira...       3.0        3.0
#
#          date  sale_price  observation_date  year    cpi  sale_price_cpi   age
# 0  2020-11-01  191.143369        2020-11-01  2020  260.4       13.823924  70.0
# 1  2020-11-01  180.557648        2020-11-01  2020  260.4       13.435637  63.0
#
# [2 rows x 24 columns]

# %%
hoods = gpd.read_file('Los Angeles Neighborhood Map.geojson')
hoods['polygon'] = hoods['geometry'].apply(lambda x: Polygon(x[0]))
hoods.head(2)
# Out:
#         external_i             name  \
# 0            acton            Acton
# 1  adams-normandie  Adams-Normandie
#
#                                         location             latitude slug_1  \
# 0  POINT(34.497355239240846 -118.16981019229348)  -118.16981019229348   None
# 1  POINT(34.031461499124156 -118.30020800000011)  -118.30020800000011   None
#
#              sqmi                                         display_na  \
# 0   39.3391089485           Acton L.A. County Neighborhood (Current)
# 1  0.805350187789  Adams-Normandie L.A. County Neighborhood (Curr...
#
#                                    set             slug           longitude  \
# 0  L.A. County Neighborhoods (Current)            acton  34.497355239240846
# 1  L.A. County Neighborhoods (Current)  adams-normandie  34.031461499124156
#
#   name_1                                kind                 type  \
# 0   None  L.A. County Neighborhood (Current)  unincorporated-area
# 1   None  L.A. County Neighborhood (Current)    segment-of-a-city
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-118.20262 34.53899, -118.1894...
# 1  MULTIPOLYGON (((-118.30901 34.03741, -118.3004...
#
#                                              polygon
# 0  POLYGON ((-118.20262 34.53899, -118.18947 34.5...
# 1  POLYGON ((-118.30901 34.03741, -118.30041 34.0...

# %%
#Turn the lat, long info into a geometry point
gdf = gpd.GeoDataFrame(houses, geometry=[Point(xy) for xy in zip(houses.longitude, houses.latitude)])
gdf.head(2)
# Out:
#     latitude   longitude           address            property_type  \
# 0  34.190532 -118.145081  2694 Raymond Ave  Single Family Residence
# 1  33.899958 -117.990815  14520 Dunnet Ave  Single Family Residence
#
#    home_size  lot_size  year_built  parcel_number  zoning  sex_offenders  ...  \
# 0     1199.0    7207.0      1950.0     5835035008  LCR175              5  ...
# 1     1254.0    6033.0      1957.0     8065036010    LMR1              2  ...
#
#   bedrooms  bathrooms        date  sale_price observation_date  year    cpi  \
# 0      3.0        2.0  2020-11-01  191.143369       2020-11-01  2020  260.4
# 1      3.0        3.0  2020-11-01  180.557648       2020-11-01  2020  260.4
#
#   sale_price_cpi   age                     geometry
# 0      13.823924  70.0  POINT (-118.14508 34.19053)
# 1      13.435637  63.0  POINT (-117.99081 33.89996)
#
# [2 rows x 25 columns]

# %%
#This function will classify every house and label it an appropriate neighborhood
def find_neighborhood(coordinates):
    for index, hood in hoods.iterrows():
        if hood['polygon'].contains(coordinates):
            return hood['name']
        else:
            continue 

gdf['neighborhood'] = gdf['geometry'].apply(find_neighborhood)
gdf.head()
# Out:
#     latitude   longitude              address            property_type  \
# 0  34.190532 -118.145081     2694 Raymond Ave  Single Family Residence
# 1  33.899958 -117.990815     14520 Dunnet Ave  Single Family Residence
# 2  34.219352 -118.205306  5195 La Canada Blvd  Single Family Residence
# 3  33.894516 -118.245489      1365 W 152nd St  Single Family Residence
# 4  34.162450 -117.901663  27 Rock Springs Way  Single Family Residence
#
#    home_size  lot_size  year_built  parcel_number  zoning  sex_offenders  ...  \
# 0     1199.0    7207.0      1950.0     5835035008  LCR175              5  ...
# 1     1254.0    6033.0      1957.0     8065036010    LMR1              2  ...
# 2     2075.0   16153.0      1955.0     5811014021  LFR120              0  ...
# 3      912.0    5241.0      1911.0     6142024036    CORL             22  ...
# 4     2580.0    6360.0      2003.0     8684049004    AZRA              2  ...
#
#   bathrooms        date  sale_price observation_date  year    cpi  \
# 0       2.0  2020-11-01  191.143369       2020-11-01  2020  260.4
# 1       3.0  2020-11-01  180.557648       2020-11-01  2020  260.4
# 2       2.0  2020-11-01  197.083809       2020-11-01  2020  260.4
# 3       1.0  2020-11-01  169.442364       2020-11-01  2020  260.4
# 4       3.0  2020-11-01  184.752441       2020-11-01  2020  260.4
#
#    sale_price_cpi    age                     geometry          neighborhood
# 0       13.823924   70.0  POINT (-118.14508 34.19053)              Altadena
# 1       13.435637   63.0  POINT (-117.99081 33.89996)             La Mirada
# 2       14.037117   65.0  POINT (-118.20531 34.21935)  La Canada Flintridge
# 3       13.015466  109.0  POINT (-118.24549 33.89452)               Compton
# 4       13.590830   17.0  POINT (-117.90166 34.16245)                 Azusa
#
# [5 rows x 26 columns]

# %%
print(f'There are  {gdf.neighborhood.isnull().sum()} out of {gdf.shape[0]} missing classifications.')
gdf.drop('geometry', axis=1, inplace=True)
gdf['neighborhood'].fillna('Missing', inplace=True)
gdf.to_csv('Data/houses_neighborhood_info.csv', index=False)
gdf.head()
# Out:
# There are  555 out of 5947 missing classifications.
#     latitude   longitude              address            property_type  \
# 0  34.190532 -118.145081     2694 Raymond Ave  Single Family Residence
# 1  33.899958 -117.990815     14520 Dunnet Ave  Single Family Residence
# 2  34.219352 -118.205306  5195 La Canada Blvd  Single Family Residence
# 3  33.894516 -118.245489      1365 W 152nd St  Single Family Residence
# 4  34.162450 -117.901663  27 Rock Springs Way  Single Family Residence
#
#    home_size  lot_size  year_built  parcel_number  zoning  sex_offenders  ...  \
# 0     1199.0    7207.0      1950.0     5835035008  LCR175              5  ...
# 1     1254.0    6033.0      1957.0     8065036010    LMR1              2  ...
# 2     2075.0   16153.0      1955.0     5811014021  LFR120              0  ...
# 3      912.0    5241.0      1911.0     6142024036    CORL             22  ...
# 4     2580.0    6360.0      2003.0     8684049004    AZRA              2  ...
#
#   bedrooms  bathrooms        date  sale_price observation_date  year    cpi  \
# 0      3.0        2.0  2020-11-01  191.143369       2020-11-01  2020  260.4
# 1      3.0        3.0  2020-11-01  180.557648       2020-11-01  2020  260.4
# 2      3.0        2.0  2020-11-01  197.083809       2020-11-01  2020  260.4
# 3      2.0        1.0  2020-11-01  169.442364       2020-11-01  2020  260.4
# 4      4.0        3.0  2020-11-01  184.752441       2020-11-01  2020  260.4
#
#   sale_price_cpi    age          neighborhood
# 0      13.823924   70.0              Altadena
# 1      13.435637   63.0             La Mirada
# 2      14.037117   65.0  La Canada Flintridge
# 3      13.015466  109.0               Compton
# 4      13.590830   17.0                 Azusa
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Create a DataFrame for the Basic Search component in the app

# %%
#Create a dataframe that will be used by the app
#Sale Price per neighborhood

avg = gdf.groupby('neighborhood')[['home_size', 'lot_size', 'sex_offenders', 
                                   'enviornmental_hazards', 'age', 'sale_price']].mean()

avg['sale_price'] = avg['sale_price'].apply(lambda x: '${:,.2f}'.format(x))

avg.to_csv('Data/Neighborhoods_final.csv')
